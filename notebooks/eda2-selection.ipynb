# %% [markdown]
# # Exploratory Data Analysis

# %%
import os

os.chdir("../")
os.getcwd()
# Out:
# '/home/hellsdeur/Documents/ufpa/cbcc/2022.2/simulation/magrela-sim'

# %%
from src.eda import Selector

# %% [markdown]
# ## 2. Data Selection

# %%
selector = Selector()

# %%
selector.read(directory="data/extracted/open_data_year_one/")
selector.read(directory="data/extracted/open_data_year_two/")
selector.read(directory="data/extracted/open_data_2016-12/")

# %%
selector.dfs.keys()
# Out:
# dict_keys(['2015_station_data', '2015_trip_data', '2015_weather_data', '2015_status_data', '2016_station_data', '2016_weather_data', '2016_trip_data', '2016-12_station_data', '2016-12_trip_data'])

# %% [markdown]
# ### Year One

# %%
selector.dfs["2015_weather_data"]
# Out:
#            Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0    10/13/2014               71.0                62.0              54.0
# 1    10/14/2014               63.0                59.0              55.0
# 2    10/15/2014               62.0                58.0              54.0
# 3    10/16/2014               71.0                61.0              52.0
# 4    10/17/2014               64.0                60.0              57.0
# ..          ...                ...                 ...               ...
# 361   10/9/2015               70.0                62.0              55.0
# 362  10/10/2015               72.0                66.0              60.0
# 363  10/11/2015               66.0                60.0              54.0
# 364  10/12/2015               68.0                61.0              54.0
# 365         NaN                NaN                 NaN               NaN
#
#      Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# ...

# %%
selector.dfs["2015_station_data"]
# Out:
#     id                                               name terminal        lat  \
# 0    1                                 3rd Ave & Broad St    BT-01  47.618418
# 1    2                                  2nd Ave & Vine St    BT-03  47.615829
# 2    3                             6th Ave & Blanchard St    BT-04  47.616094
# 3    4                             2nd Ave & Blanchard St    BT-05  47.613110
# 4    5                                  2nd Ave & Pine St   CBD-13  47.610185
# 5    6                                 7th Ave & Union St   CBD-03  47.610731
# 6    7                     City Hall / 4th Ave & James St   CBD-07  47.603509
# 7    8                                  Pine St & 9th Ave   SLU-16  47.613715
# 8    9                                2nd Ave & Spring St   CBD-06  47.605950
# 9   10                           Summit Ave & E Denny Way    CH-01  47.618633
# 10  11                     E Harrison St & Broadway Ave E    CH-02  47.622063
# ...

# %%
selector.dfs["2015_trip_data"]
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 0           431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1           432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2           433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3           434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4           435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# ...         ...               ...               ...       ...           ...
# 142841   156796  10/12/2015 20:41  10/12/2015 20:47  SEA00358       377.183
# 142842   156797  10/12/2015 20:43  10/12/2015 20:48  SEA00399       303.330
# 142843   156798  10/12/2015 21:03  10/12/2015 21:06  SEA00204       165.597
# 142844   156799  10/12/2015 21:35  10/12/2015 21:41  SEA00073       388.576
# 142845   156800  10/12/2015 22:45  10/12/2015 22:51  SEA00033       391.885
#
#                      from_station_name  \
# ...

# %%
selector.dfs["2015_status_data"]
# Out:
#           station_id  bikes_available  docks_available  bikes_blocked  \
# 0                  1                0               16              2
# 1                  2                4               12              0
# 2                  3                7                8              1
# 3                  4                3               11              0
# 4                  5                7               10              1
# ...              ...              ...              ...            ...
# 26061833          50                7               13              0
# 26061834          60                6               10              0
# 26061835          62                6               14              0
# 26061836          63                8                9              1
# 26061837          65                4               16              0
#
#           docks_blocked                 time
# 0                     0  2014-10-15 08:29:47
# ...

# %% [markdown]
# ### Year Two - Part 1

# %%
selector.dfs["2016_station_data"]
# Out:
#    station_id                                               name        lat  \
# 0       BT-01                                 3rd Ave & Broad St  47.618418
# 1       BT-03                                  2nd Ave & Vine St  47.615829
# 2       BT-04                             6th Ave & Blanchard St  47.616094
# 3       BT-05                             2nd Ave & Blanchard St  47.613110
# 4      CBD-03                                 7th Ave & Union St  47.610731
# 5      CBD-04                                 Union St & 4th Ave  47.609221
# 6      CBD-05                                1st Ave & Marion St  47.604058
# 7      CBD-06                                2nd Ave & Spring St  47.605950
# 8      CBD-07                     City Hall / 4th Ave & James St  47.603509
# 9      CBD-13                                  2nd Ave & Pine St  47.610185
# 10      CD-01                            12th Ave & E Yesler Way  47.602103
# ...

# %%
selector.dfs["2016_weather_data"]
# Out:
#            Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0    10/13/2014                 71                62.0                54
# 1    10/14/2014                 63                59.0                55
# 2    10/15/2014                 62                58.0                54
# 3    10/16/2014                 71                61.0                52
# 4    10/17/2014                 64                60.0                57
# ..          ...                ...                 ...               ...
# 684   8/27/2016                 72                66.0                61
# 685   8/28/2016                 75                68.0                59
# 686   8/29/2016                 81                68.0                55
# 687   8/30/2016                 70                64.0                57
# 688   8/31/2016                 71                65.0                59
#
#      Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# ...

# %%
selector.dfs["2016_trip_data"]
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 0           431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1           432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2           433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3           434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4           435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# ...         ...               ...               ...       ...           ...
# 236060   255241   8/31/2016 23:34   8/31/2016 23:45  SEA00201       679.532
# 236061   255242   8/31/2016 23:48     9/1/2016 0:20  SEA00247      1965.418
# 236062   255243   8/31/2016 23:47     9/1/2016 0:20  SEA00300      1951.173
# 236063   255244   8/31/2016 23:49     9/1/2016 0:20  SEA00047      1883.299
# 236064   255245   8/31/2016 23:49     9/1/2016 0:20  SEA00442      1896.031
#
#                              from_station_name  \
# ...

# %% [markdown]
# ### Year Two - Part 2

# %%
selector.dfs["2016-12_station_data"]
# Out:
#    station_id                                               name        lat  \
# 0       CH-06                             12th Ave & E Denny Way  47.618549
# 1       CH-15                             12th Ave & E Mercer St  47.624142
# 2       CD-01                            12th Ave & E Yesler Way  47.602103
# 3       UD-04                          12th Ave & NE Campus Pkwy  47.656395
# 4       CH-05                           15th Ave E & E Thomas St  47.620712
# 5       UW-04                           15th Ave NE & NE 40th St  47.655590
# 6      CBD-05                                1st Ave & Marion St  47.604058
# 7       BT-05                             2nd Ave & Blanchard St  47.613110
# 8      CBD-13                                  2nd Ave & Pine St  47.610185
# 9      CBD-06                                2nd Ave & Spring St  47.605950
# 10      BT-03                                  2nd Ave & Vine St  47.615829
# ...

# %%
selector.dfs["2016-12_trip_data"]
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 0           431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1           432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2           433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3           434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4           435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# ...         ...               ...               ...       ...           ...
# 263131   283148  12/31/2016 23:01  12/31/2016 23:37  SEA00220      2139.413
# 263132   283149  12/31/2016 23:41     1/1/2017 0:18  SEA00339      2185.038
# 263133   283150  12/31/2016 23:42     1/1/2017 0:18  SEA00126      2173.435
# 263134   283151  12/31/2016 23:47     1/1/2017 0:18  SEA00014      1850.632
# 263135   283152  12/31/2016 23:47     1/1/2017 0:18  SEA00343      1857.877
#
# ...

# %% [markdown]
# ### Selection decision

# %% [markdown]
# Given the heterogeneity of the data through the years, the data used in the current analysis and in the simulation project will only take into account data related to the "Year One" section. Furthermore, data for "Year One" is the most complete of the three sets, containing not only trip and station data, but also status and weather.

# %%
data = {
    "trip": selector.dfs["2015_trip_data"],
    "station": selector.dfs["2015_station_data"],
    "status": selector.dfs["2015_status_data"],
    "weather": selector.dfs["2015_weather_data"]
}

# %%
selector.serialize(data=data, serial_path="data/selected.pickle")
